# %%
#Тест для прокудина горского
# %matplotlib inline
from skimage.io import imread,imshow,imsave 
from skimage import img_as_float, img_as_ubyte 
from numpy import dstack

img_0 = imread('C:\\Users\\Elena\\Documents\\stepik\\images_course\\00.png')

img_0_f = img_as_float(img_0)

#выделям три канала
img0_size = img_0_f.shape[0]//3
img0_b = img_0_f[:img0_size, :]
img0_g = img_0_f[img0_size:img0_size*2, :]
img0_r = img_0_f[img0_size*2:img0_size*3, :]

#обрезаем с крайев по 5%
a = img0_r.shape[0]
b = img0_r.shape[1]
p = 0.07
img0_r = img0_r[round(a*p):a-round(a*p), round(b*p) : b - round(b*p)]

a1 = img0_g.shape[0]
b1 = img0_g.shape[1]
img0_g = img0_g[round(a1*p):a1-round(a1*p), round(b1*p) : b1 - round(b1*p)]

a2 = img0_b.shape[0]
b2 = img0_b.shape[1]
img0_b = img0_b[round(a2*p):a2-round(a2*p), round(b2*p) : b2 - round(b2*p)]

#сдвигаем синий канал, накладываем на зеленый, считаем похожесть
#величина корреляции прямо пропорциональна похожести
import numpy as np
max_corr,bcor_i, bcor_j = 0 , 0, 0
for i in range (-15,16):
    for j in range (-15,16):
        b_g = np.roll(img0_b, i, axis=0)
        b_v = np.roll(b_g, j, axis=1)
        correlation = (b_v*img0_g).sum()
        if correlation > max_corr:
            bcor_i, bcor_j = i, j
            max_corr = correlation
print(bcor_i, bcor_j)

#сдвигаем красный канал, накладываем на зеленый, считаем похожесть
max_corr, rcor_i, rcor_j = 0 , 0, 0
correlation = 0
for i in range (-15,16):
    for j in range (-15,16):
        r_g = np.roll(img0_r, i, axis=0)
        r_v = np.roll(r_g, j, axis=1)
        correlation = (r_v*img0_g).sum()
        if correlation > max_corr:
            rcor_i, rcor_j = i, j
            max_corr = correlation
print(rcor_i, rcor_j)

#совмещаем три канала с наилучшими сдвигами
r_rez_1 = np.roll(img0_r, rcor_i, axis=0)
r_rez = np.roll(r_rez_1, rcor_j, axis=1)

b_rez_1 = np.roll(img0_b, bcor_i, axis=0)
b_rez = np.roll(b_rez_1, bcor_j, axis=1)

img0_rez = dstack((r_rez, img0_g, b_rez))
imshow(img0_rez)
# Out:
# -3 1
# 9 -1

# %%
img_0 = imread('C:\\Users\\Elena\\Documents\\stepik\\images_course\\01.png')

img_0_f = img_as_float(img_0)

#выделям три канала
img0_size = img_0_f.shape[0]//3
img0_b = img_0_f[:img0_size, :]
img0_g = img_0_f[img0_size:img0_size*2, :]
img0_r = img_0_f[img0_size*2:img0_size*3, :]

#обрезаем с крайев по 5%
a = img0_r.shape[0]
b = img0_r.shape[1]
p = 0.07
img0_r = img0_r[round(a*p):a-round(a*p), round(b*p) : b - round(b*p)]

a1 = img0_g.shape[0]
b1 = img0_g.shape[1]
img0_g = img0_g[round(a1*p):a1-round(a1*p), round(b1*p) : b1 - round(b1*p)]

a2 = img0_b.shape[0]
b2 = img0_b.shape[1]
img0_b = img0_b[round(a2*p):a2-round(a2*p), round(b2*p) : b2 - round(b2*p)]

#сдвигаем синий канал, накладываем на зеленый, считаем похожесть
#величина корреляции прямо пропорциональна похожести
import numpy as np
max_corr,bcor_i, bcor_j = 0 , 0, 0
for i in range (-15,16):
    for j in range (-15,16):
        b_g = np.roll(img0_b, i, axis=0)
        b_v = np.roll(b_g, j, axis=1)
        correlation = (b_v*img0_g).sum()
        if correlation > max_corr:
            bcor_i, bcor_j = i, j
            max_corr = correlation
print(bcor_i, bcor_j)

#сдвигаем красный канал, накладываем на зеленый, считаем похожесть
max_corr, rcor_i, rcor_j = 0 , 0, 0
correlation = 0
for i in range (-15,16):
    for j in range (-15,16):
        r_g = np.roll(img0_r, i, axis=0)
        r_v = np.roll(r_g, j, axis=1)
        correlation = (r_v*img0_g).sum()
        if correlation > max_corr:
            rcor_i, rcor_j = i, j
            max_corr = correlation
print(rcor_i, rcor_j)

#совмещаем три канала с наилучшими сдвигами
r_rez_1 = np.roll(img0_r, rcor_i, axis=0)
r_rez = np.roll(r_rez_1, rcor_j, axis=1)

b_rez_1 = np.roll(img0_b, bcor_i, axis=0)
b_rez = np.roll(b_rez_1, bcor_j, axis=1)

img0_rez = dstack((r_rez, img0_g, b_rez))
imshow(img0_rez)
# Out:
# -3 0
# 8 1

# %%
#Тест для прокудина горского
# %matplotlib inline
from skimage.io import imread,imshow,imsave 
from skimage import img_as_float, img_as_ubyte 
from numpy import dstack

img_0 = imread('C:\\Users\\Elena\\Documents\\stepik\\images_course\\03.png')

img_0_f = img_as_float(img_0)

#выделям три канала
img0_size = img_0_f.shape[0]//3
img0_b = img_0_f[:img0_size, :]
img0_g = img_0_f[img0_size:img0_size*2, :]
img0_r = img_0_f[img0_size*2:img0_size*3, :]

#обрезаем с крайев по 5%
a = img0_r.shape[0]
b = img0_r.shape[1]
img0_r = img0_r[round(a*0.1):a-round(a*0.1), round(b*0.1) : b - round(b*0.1)]

a1 = img0_g.shape[0]
b1 = img0_g.shape[1]
img0_g = img0_g[round(a1*0.1):a1-round(a1*0.1), round(b1*0.1) : b1 - round(b1*0.1)]

a2 = img0_b.shape[0]
b2 = img0_b.shape[1]
img0_b = img0_b[round(a2*0.1):a2-round(a2*0.1), round(b2*0.1) : b2 - round(b2*0.1)]

#сдвигаем синий канал, накладываем на зеленый, считаем похожесть
#величина корреляции прямо пропорциональна похожести
import numpy as np
max_corr,bcor_i, bcor_j = 0 , 0, 0
for i in range (-15,16):
    for j in range (-15,16):
        b_g = np.roll(img0_b, i, axis=0)
        b_v = np.roll(b_g, j, axis=1)
        correlation = (b_v*img0_g).sum()
        if correlation > max_corr:
            bcor_i, bcor_j = i, j
            max_corr = correlation
print(bcor_i, bcor_j)

#сдвигаем красный канал, накладываем на зеленый, считаем похожесть
max_corr, rcor_i, rcor_j = 0 , 0, 0
correlation = 0
for i in range (-15,16):
    for j in range (-15,16):
        r_g = np.roll(img0_r, i, axis=0)
        r_v = np.roll(r_g, j, axis=1)
        correlation = (r_v*img0_g).sum()
        if correlation > max_corr:
            rcor_i, rcor_j = i, j
            max_corr = correlation
print(rcor_i, rcor_j)

#совмещаем три канала с наилучшими сдвигами
r_rez_1 = np.roll(img0_r, rcor_i, axis=0)
r_rez = np.roll(r_rez_1, rcor_j, axis=1)

b_rez_1 = np.roll(img0_b, bcor_i, axis=0)
b_rez = np.roll(b_rez_1, bcor_j, axis=1)

img0_rez = dstack((r_rez, img0_g, b_rez))
imshow(img0_rez)
# Out:
# -4 -1
# 5 3

# %%
img_0 = imread('C:\\Users\\Elena\\Documents\\stepik\\images_course\\02.png')

img_0_f = img_as_float(img_0)

#выделям три канала
img0_size = img_0_f.shape[0]//3
img0_b = img_0_f[:img0_size, :]
img0_g = img_0_f[img0_size:img0_size*2, :]
img0_r = img_0_f[img0_size*2:img0_size*3, :]

#обрезаем с крайев по 5%
a = img0_r.shape[0]
b = img0_r.shape[1]
p = 0.07
img0_r = img0_r[round(a*p):a-round(a*p), round(b*p) : b - round(b*p)]

a1 = img0_g.shape[0]
b1 = img0_g.shape[1]
img0_g = img0_g[round(a1*p):a1-round(a1*p), round(b1*p) : b1 - round(b1*p)]

a2 = img0_b.shape[0]
b2 = img0_b.shape[1]
img0_b = img0_b[round(a2*p):a2-round(a2*p), round(b2*p) : b2 - round(b2*p)]

#сдвигаем синий канал, накладываем на зеленый, считаем похожесть
#величина корреляции прямо пропорциональна похожести
import numpy as np
max_corr,bcor_i, bcor_j = 0 , 0, 0
for i in range (-15,16):
    for j in range (-15,16):
        b_g = np.roll(img0_b, i, axis=0)
        b_v = np.roll(b_g, j, axis=1)
        correlation = (b_v*img0_g).sum()
        if correlation > max_corr:
            bcor_i, bcor_j = i, j
            max_corr = correlation
print(bcor_i, bcor_j)

#сдвигаем красный канал, накладываем на зеленый, считаем похожесть
max_corr, rcor_i, rcor_j = 0 , 0, 0
correlation = 0
for i in range (-15,16):
    for j in range (-15,16):
        r_g = np.roll(img0_r, i, axis=0)
        r_v = np.roll(r_g, j, axis=1)
        correlation = (r_v*img0_g).sum()
        if correlation > max_corr:
            rcor_i, rcor_j = i, j
            max_corr = correlation
print(rcor_i, rcor_j)

#совмещаем три канала с наилучшими сдвигами
r_rez_1 = np.roll(img0_r, rcor_i, axis=0)
r_rez = np.roll(r_rez_1, rcor_j, axis=1)

b_rez_1 = np.roll(img0_b, bcor_i, axis=0)
b_rez = np.roll(b_rez_1, bcor_j, axis=1)

img0_rez = dstack((r_rez, img0_g, b_rez))
imshow(img0_rez)
# Out:
# -5 -2
# 7 1

# %%
img_0 = imread('C:\\Users\\Elena\\Documents\\stepik\\images_course\\04.png')

img_0_f = img_as_float(img_0)

#выделям три канала
img0_size = img_0_f.shape[0]//3
img0_b = img_0_f[:img0_size, :]
img0_g = img_0_f[img0_size:img0_size*2, :]
img0_r = img_0_f[img0_size*2:img0_size*3, :]

#обрезаем с крайев по 5%
a = img0_r.shape[0]
b = img0_r.shape[1]
img0_r = img0_r[round(a*0.1):a-round(a*0.1), round(b*0.1) : b - round(b*0.1)]

a1 = img0_g.shape[0]
b1 = img0_g.shape[1]
img0_g = img0_g[round(a1*0.1):a1-round(a1*0.1), round(b1*0.1) : b1 - round(b1*0.1)]

a2 = img0_b.shape[0]
b2 = img0_b.shape[1]
img0_b = img0_b[round(a2*0.1):a2-round(a2*0.1), round(b2*0.1) : b2 - round(b2*0.1)]

#сдвигаем синий канал, накладываем на зеленый, считаем похожесть
#величина корреляции прямо пропорциональна похожести
import numpy as np
max_corr,bcor_i, bcor_j = 0 , 0, 0
for i in range (-15,16):
    for j in range (-15,16):
        b_g = np.roll(img0_b, i, axis=0)
        b_v = np.roll(b_g, j, axis=1)
        correlation = (b_v*img0_g).sum()
        if correlation > max_corr:
            bcor_i, bcor_j = i, j
            max_corr = correlation
print(bcor_i, bcor_j)

#сдвигаем красный канал, накладываем на зеленый, считаем похожесть
max_corr, rcor_i, rcor_j = 0 , 0, 0
correlation = 0
for i in range (-15,16):
    for j in range (-15,16):
        r_g = np.roll(img0_r, i, axis=0)
        r_v = np.roll(r_g, j, axis=1)
        correlation = (r_v*img0_g).sum()
        if correlation > max_corr:
            rcor_i, rcor_j = i, j
            max_corr = correlation
print(rcor_i, rcor_j)

#совмещаем три канала с наилучшими сдвигами
r_rez_1 = np.roll(img0_r, rcor_i, axis=0)
r_rez = np.roll(r_rez_1, rcor_j, axis=1)

b_rez_1 = np.roll(img0_b, bcor_i, axis=0)
b_rez = np.roll(b_rez_1, bcor_j, axis=1)

img0_rez = dstack((r_rez, img0_g, b_rez))
imshow(img0_rez)
# Out:
# 2 -1
# 3 1

# %%
img_0 = imread('C:\\Users\\Elena\\Documents\\stepik\\images_course\\05.png')

img_0_f = img_as_float(img_0)

#выделям три канала
img0_size = img_0_f.shape[0]//3
img0_b = img_0_f[:img0_size, :]
img0_g = img_0_f[img0_size:img0_size*2, :]
img0_r = img_0_f[img0_size*2:img0_size*3, :]

#обрезаем с крайев по 5%
a = img0_r.shape[0]
b = img0_r.shape[1]
img0_r = img0_r[round(a*0.1):a-round(a*0.1), round(b*0.1) : b - round(b*0.1)]

a1 = img0_g.shape[0]
b1 = img0_g.shape[1]
img0_g = img0_g[round(a1*0.1):a1-round(a1*0.1), round(b1*0.1) : b1 - round(b1*0.1)]

a2 = img0_b.shape[0]
b2 = img0_b.shape[1]
img0_b = img0_b[round(a2*0.1):a2-round(a2*0.1), round(b2*0.1) : b2 - round(b2*0.1)]

#сдвигаем синий канал, накладываем на зеленый, считаем похожесть
#величина корреляции прямо пропорциональна похожести
import numpy as np
max_corr,bcor_i, bcor_j = 0 , 0, 0
for i in range (-15,16):
    for j in range (-15,16):
        b_g = np.roll(img0_b, i, axis=0)
        b_v = np.roll(b_g, j, axis=1)
        correlation = (b_v*img0_g).sum()
        if correlation > max_corr:
            bcor_i, bcor_j = i, j
            max_corr = correlation
print(bcor_i, bcor_j)

#сдвигаем красный канал, накладываем на зеленый, считаем похожесть
max_corr, rcor_i, rcor_j = 0 , 0, 0
correlation = 0
for i in range (-15,16):
    for j in range (-15,16):
        r_g = np.roll(img0_r, i, axis=0)
        r_v = np.roll(r_g, j, axis=1)
        correlation = (r_v*img0_g).sum()
        if correlation > max_corr:
            rcor_i, rcor_j = i, j
            max_corr = correlation
print(rcor_i, rcor_j)

#совмещаем три канала с наилучшими сдвигами
r_rez_1 = np.roll(img0_r, rcor_i, axis=0)
r_rez = np.roll(r_rez_1, rcor_j, axis=1)

b_rez_1 = np.roll(img0_b, bcor_i, axis=0)
b_rez = np.roll(b_rez_1, bcor_j, axis=1)

img0_rez = dstack((r_rez, img0_g, b_rez))
imshow(img0_rez)
# Out:
# -3 -2
# 5 2

# %%
img_0 = imread('C:\\Users\\Elena\\Documents\\stepik\\images_course\\06.png')

img_0_f = img_as_float(img_0)

#выделям три канала
img0_size = img_0_f.shape[0]//3
img0_b = img_0_f[:img0_size, :]
img0_g = img_0_f[img0_size:img0_size*2, :]
img0_r = img_0_f[img0_size*2:img0_size*3, :]

#обрезаем с крайев по 5%
a = img0_r.shape[0]
b = img0_r.shape[1]
img0_r = img0_r[round(a*0.1):a-round(a*0.1), round(b*0.1) : b - round(b*0.1)]

a1 = img0_g.shape[0]
b1 = img0_g.shape[1]
img0_g = img0_g[round(a1*0.1):a1-round(a1*0.1), round(b1*0.1) : b1 - round(b1*0.1)]

a2 = img0_b.shape[0]
b2 = img0_b.shape[1]
img0_b = img0_b[round(a2*0.1):a2-round(a2*0.1), round(b2*0.1) : b2 - round(b2*0.1)]

#сдвигаем синий канал, накладываем на зеленый, считаем похожесть
#величина корреляции прямо пропорциональна похожести
import numpy as np
max_corr,bcor_i, bcor_j = 0 , 0, 0
for i in range (-15,16):
    for j in range (-15,16):
        b_g = np.roll(img0_b, i, axis=0)
        b_v = np.roll(b_g, j, axis=1)
        correlation = (b_v*img0_g).sum()
        if correlation > max_corr:
            bcor_i, bcor_j = i, j
            max_corr = correlation
print(bcor_i, bcor_j)

#сдвигаем красный канал, накладываем на зеленый, считаем похожесть
max_corr, rcor_i, rcor_j = 0 , 0, 0
correlation = 0
for i in range (-15,16):
    for j in range (-15,16):
        r_g = np.roll(img0_r, i, axis=0)
        r_v = np.roll(r_g, j, axis=1)
        correlation = (r_v*img0_g).sum()
        if correlation > max_corr:
            rcor_i, rcor_j = i, j
            max_corr = correlation
print(rcor_i, rcor_j)

#совмещаем три канала с наилучшими сдвигами
r_rez_1 = np.roll(img0_r, rcor_i, axis=0)
r_rez = np.roll(r_rez_1, rcor_j, axis=1)

b_rez_1 = np.roll(img0_b, bcor_i, axis=0)
b_rez = np.roll(b_rez_1, bcor_j, axis=1)

img0_rez = dstack((r_rez, img0_g, b_rez))
imshow(img0_rez)
# Out:
# -5 -3
# 7 3

# %%
img_0 = imread('C:\\Users\\Elena\\Documents\\stepik\\images_course\\07.png')

img_0_f = img_as_float(img_0)

#выделям три канала
img0_size = img_0_f.shape[0]//3
img0_b = img_0_f[:img0_size, :]
img0_g = img_0_f[img0_size:img0_size*2, :]
img0_r = img_0_f[img0_size*2:img0_size*3, :]

#обрезаем с крайев по 5%
a = img0_r.shape[0]
b = img0_r.shape[1]
p = 0.07
img0_r = img0_r[round(a*p):a-round(a*p), round(b*p) : b - round(b*p)]

a1 = img0_g.shape[0]
b1 = img0_g.shape[1]
img0_g = img0_g[round(a1*p):a1-round(a1*p), round(b1*p) : b1 - round(b1*p)]

a2 = img0_b.shape[0]
b2 = img0_b.shape[1]
img0_b = img0_b[round(a2*p):a2-round(a2*p), round(b2*p) : b2 - round(b2*p)]

#сдвигаем синий канал, накладываем на зеленый, считаем похожесть
#величина корреляции прямо пропорциональна похожести
import numpy as np
max_corr,bcor_i, bcor_j = 0 , 0, 0
for i in range (-15,16):
    for j in range (-15,16):
        b_g = np.roll(img0_b, i, axis=0)
        b_v = np.roll(b_g, j, axis=1)
        correlation = (b_v*img0_g).sum()
        if correlation > max_corr:
            bcor_i, bcor_j = i, j
            max_corr = correlation
print(bcor_i, bcor_j)

#сдвигаем красный канал, накладываем на зеленый, считаем похожесть
max_corr, rcor_i, rcor_j = 0 , 0, 0
correlation = 0
for i in range (-15,16):
    for j in range (-15,16):
        r_g = np.roll(img0_r, i, axis=0)
        r_v = np.roll(r_g, j, axis=1)
        correlation = (r_v*img0_g).sum()
        if correlation > max_corr:
            rcor_i, rcor_j = i, j
            max_corr = correlation
print(rcor_i, rcor_j)

#совмещаем три канала с наилучшими сдвигами
r_rez_1 = np.roll(img0_r, rcor_i, axis=0)
r_rez = np.roll(r_rez_1, rcor_j, axis=1)

b_rez_1 = np.roll(img0_b, bcor_i, axis=0)
b_rez = np.roll(b_rez_1, bcor_j, axis=1)

img0_rez = dstack((r_rez, img0_g, b_rez))
imshow(img0_rez)
# Out:
# -7 0
# 8 -1

# %%
img_0 = imread('C:\\Users\\Elena\\Documents\\stepik\\images_course\\08.png')

img_0_f = img_as_float(img_0)

#выделям три канала
img0_size = img_0_f.shape[0]//3
img0_b = img_0_f[:img0_size, :]
img0_g = img_0_f[img0_size:img0_size*2, :]
img0_r = img_0_f[img0_size*2:img0_size*3, :]

#обрезаем с крайев по 5%
a = img0_r.shape[0]
b = img0_r.shape[1]
p = 0.07
img0_r = img0_r[round(a*p):a-round(a*p), round(b*p) : b - round(b*p)]

a1 = img0_g.shape[0]
b1 = img0_g.shape[1]
img0_g = img0_g[round(a1*p):a1-round(a1*p), round(b1*p) : b1 - round(b1*p)]

a2 = img0_b.shape[0]
b2 = img0_b.shape[1]
img0_b = img0_b[round(a2*p):a2-round(a2*p), round(b2*p) : b2 - round(b2*p)]

#сдвигаем синий канал, накладываем на зеленый, считаем похожесть
#величина корреляции прямо пропорциональна похожести
import numpy as np
max_corr,bcor_i, bcor_j = 0 , 0, 0
for i in range (-15,16):
    for j in range (-15,16):
        b_g = np.roll(img0_b, i, axis=0)
        b_v = np.roll(b_g, j, axis=1)
        correlation = (b_v*img0_g).sum()
        if correlation > max_corr:
            bcor_i, bcor_j = i, j
            max_corr = correlation
print(bcor_i, bcor_j)

#сдвигаем красный канал, накладываем на зеленый, считаем похожесть
max_corr, rcor_i, rcor_j = 0 , 0, 0
correlation = 0
for i in range (-15,16):
    for j in range (-15,16):
        r_g = np.roll(img0_r, i, axis=0)
        r_v = np.roll(r_g, j, axis=1)
        correlation = (r_v*img0_g).sum()
        if correlation > max_corr:
            rcor_i, rcor_j = i, j
            max_corr = correlation
print(rcor_i, rcor_j)

#совмещаем три канала с наилучшими сдвигами
r_rez_1 = np.roll(img0_r, rcor_i, axis=0)
r_rez = np.roll(r_rez_1, rcor_j, axis=1)

b_rez_1 = np.roll(img0_b, bcor_i, axis=0)
b_rez = np.roll(b_rez_1, bcor_j, axis=1)

img0_rez = dstack((r_rez, img0_g, b_rez))
imshow(img0_rez)
# Out:
# -8 -5
# 9 3

# %%
img_0 = imread('C:\\Users\\Elena\\Documents\\stepik\\images_course\\09.png')

img_0_f = img_as_float(img_0)

#выделям три канала
img0_size = img_0_f.shape[0]//3
img0_b = img_0_f[:img0_size, :]
img0_g = img_0_f[img0_size:img0_size*2, :]
img0_r = img_0_f[img0_size*2:img0_size*3, :]

#обрезаем с крайев по 5%
a = img0_r.shape[0]
b = img0_r.shape[1]
p = 0.07
img0_r = img0_r[round(a*p):a-round(a*p), round(b*p) : b - round(b*p)]

a1 = img0_g.shape[0]
b1 = img0_g.shape[1]
img0_g = img0_g[round(a1*p):a1-round(a1*p), round(b1*p) : b1 - round(b1*p)]

a2 = img0_b.shape[0]
b2 = img0_b.shape[1]
img0_b = img0_b[round(a2*p):a2-round(a2*p), round(b2*p) : b2 - round(b2*p)]

#сдвигаем синий канал, накладываем на зеленый, считаем похожесть
#величина корреляции прямо пропорциональна похожести
import numpy as np
max_corr,bcor_i, bcor_j = 0 , 0, 0
for i in range (-15,16):
    for j in range (-15,16):
        b_g = np.roll(img0_b, i, axis=0)
        b_v = np.roll(b_g, j, axis=1)
        correlation = (b_v*img0_g).sum()
        if correlation > max_corr:
            bcor_i, bcor_j = i, j
            max_corr = correlation
print(bcor_i, bcor_j)

#сдвигаем красный канал, накладываем на зеленый, считаем похожесть
max_corr, rcor_i, rcor_j = 0 , 0, 0
correlation = 0
for i in range (-15,16):
    for j in range (-15,16):
        r_g = np.roll(img0_r, i, axis=0)
        r_v = np.roll(r_g, j, axis=1)
        correlation = (r_v*img0_g).sum()
        if correlation > max_corr:
            rcor_i, rcor_j = i, j
            max_corr = correlation
print(rcor_i, rcor_j)

#совмещаем три канала с наилучшими сдвигами
r_rez_1 = np.roll(img0_r, rcor_i, axis=0)
r_rez = np.roll(r_rez_1, rcor_j, axis=1)

b_rez_1 = np.roll(img0_b, bcor_i, axis=0)
b_rez = np.roll(b_rez_1, bcor_j, axis=1)

img0_rez = dstack((r_rez, img0_g, b_rez))
imshow(img0_rez)
# Out:
# -6 -3
# 7 2
