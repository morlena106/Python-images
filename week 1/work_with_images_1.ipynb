# %%
#для просмотра изображений в браузере
# %matplotlib inline

# %%
from skimage.io import imread, imshow, imsave

# %%
img = imread('C:\\Users\\Elena\\Documents\\stepik\\images_course\\tiger.jpg')

# %%
imshow(img)

# %%
img.shape
# Out:
# (1536, 2048, 3)

# %%
img.shape[1]
# Out:
# 2048

# %%
img[1000,1100]
# Out:
# Array([119, 117, 104], dtype=uint8)

# %%
img[1000,1100,2]
# Out:
# 104

# %%
img[1000,1100] = [255,255,0]

# %%
imsave('C:\\Users\\Elena\\Documents\\stepik\\images_course\\tiger_new.jpg',img)

# %%
img_2 = imread('https://stepik.org/media/attachments/lesson/58180/img.png')

# %%
imshow(img_2)

# %%
img_2.shape[1]
# Out:
# 419

# %%
img_3 = imread('https://stepik.org/media/attachments/lesson/58180/tiger-color.png')

# %%
imshow(img_3)

# %%
imsave('C:\\Users\\Elena\\Documents\\stepik\\images_course\\tiger_course.jpg', img_3)

# %%
img_3.shape
# Out:
# (601, 801, 3)

# %%
#скопируем прямоугольную область с носом 
nose = img_3[370:410, 350:440]

# %%
imshow(nose)

# %%
img_3[370:410, 350:440] = [255,0,255]

# %%
imshow(img_3)

# %%
#методы копирования 
img_assign = nose 
img_copy = nose.copy()

# %%
nose[20:25, 40:50] = [200, 150, 40]

# %%
imshow(nose)

# %%
imshow(img_assign)

# %%
imshow(img_copy)

# %%
img_test = imread('https://stepik.org/media/attachments/lesson/58180/tiger-gray.png')

# %%
imshow(img_test)

# %%
part = img_test[296:305, 392:409]
imshow(part)

# %%
part[4,4]
# Out:
# Array([200, 200, 200], dtype=uint8)

# %%
part[4,4,1]
# Out:
# 200

# %%
img_n = imread('https://stepik.org/media/attachments/lesson/58180/tiger-border.png')

# %%
imshow(img_n)

# %%
#нахождение размеров рамки 
import numpy as np
l = 0
v = 0 
p = 0
n = 0 
test = img_n[0,0]
sh_sr = img_n.shape[0]//2
dl_sr = img_n.shape[1]//2
for i in range (dl_sr):
    if np.array_equal(img_n[sh_sr,i], test):
        l+=1
    if np.array_equal(img_n[sh_sr,img_n.shape[1]-i-1], test):
        p+=1
for i in range (sh_sr):
    if np.array_equal(img_n[i,dl_sr,], test):
        v+=1
    if np.array_equal(img_n[img_n.shape[0]-i-1,dl_sr], test):
        n+=1
print(l,v,p,n)
# Out:
# 1 39 25 7
